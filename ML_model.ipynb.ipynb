# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Loading Boston Dataset

# %%
pip install scikit-learn==1.1.3
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached scikit-learn-1.1.3.tar.gz (7.0 MB)
#   Installing build dependencies: started
#   Installing build dependencies: still running...
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Users\Sounak\AppData\Roaming\Python\Python313\site-packages\pip\_internal\cli\base_command.py", line 106, in _run_wrapper
#     status = _inner_run()
#   File "C:\Users\Sounak\AppData\Roaming\Python\Python313\site-packages\pip\_internal\cli\base_command.py", line 97, in _inner_run
#     return self.run(options, args)
#            ~~~~~~~~^^^^^^^^^^^^^^^
# ...

# %%
from sklearn.datasets import fetch_openml

boston = fetch_openml(name='boston', version=1,as_frame=True)
print(boston.data.shape)  # To check the dataset
# Out:
# (506, 13)

# %%
boston.data
# Out:
#         CRIM    ZN  INDUS CHAS    NOX     RM   AGE     DIS RAD    TAX  \
# 0    0.00632  18.0   2.31    0  0.538  6.575  65.2  4.0900   1  296.0
# 1    0.02731   0.0   7.07    0  0.469  6.421  78.9  4.9671   2  242.0
# 2    0.02729   0.0   7.07    0  0.469  7.185  61.1  4.9671   2  242.0
# 3    0.03237   0.0   2.18    0  0.458  6.998  45.8  6.0622   3  222.0
# 4    0.06905   0.0   2.18    0  0.458  7.147  54.2  6.0622   3  222.0
# ..       ...   ...    ...  ...    ...    ...   ...     ...  ..    ...
# 501  0.06263   0.0  11.93    0  0.573  6.593  69.1  2.4786   1  273.0
# 502  0.04527   0.0  11.93    0  0.573  6.120  76.7  2.2875   1  273.0
# 503  0.06076   0.0  11.93    0  0.573  6.976  91.0  2.1675   1  273.0
# 504  0.10959   0.0  11.93    0  0.573  6.794  89.3  2.3889   1  273.0
# 505  0.04741   0.0  11.93    0  0.573  6.030  80.8  2.5050   1  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# ...

# %%
data_array = boston.data.to_numpy()

print(data_array)##boston.data
# Out:
# [[0.00632 18.0 2.31 ... 15.3 396.9 4.98]
#  [0.02731 0.0 7.07 ... 17.8 396.9 9.14]
#  [0.02729 0.0 7.07 ... 17.8 392.83 4.03]
#  ...
#  [0.06076 0.0 11.93 ... 21.0 396.9 5.64]
#  [0.10959 0.0 11.93 ... 21.0 393.45 6.48]
#  [0.04741 0.0 11.93 ... 21.0 396.9 7.88]]

# %%
type(data_array)
# Out:
# numpy.ndarray

# %%
boston.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'categories', 'feature_names', 'target_names', 'DESCR', 'details', 'url'])

# %%
print(boston.DESCR)
# Out:
# **Author**:
# **Source**: Unknown - Date unknown
# **Please cite**:
#
# The Boston house-price data of Harrison, D. and Rubinfeld, D.L. 'Hedonic
# prices and the demand for clean air', J. Environ. Economics & Management,
# vol.5, 81-102, 1978.   Used in Belsley, Kuh & Welsch, 'Regression diagnostics
# ...', Wiley, 1980.   N.B. Various transformations are used in the table on
# pages 244-261 of the latter.
# Variables in order:
# CRIM     per capita crime rate by town
# ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
# INDUS    proportion of non-retail business acres per town
# CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
# NOX      nitric oxides concentration (parts per 10 million)
# RM       average number of rooms per dwelling
# AGE      proportion of owner-occupied units built prior to 1940
# DIS      weighted distances to five Boston employment centres
# RAD      index of accessibility to radial highways
# ...

# %%
print(boston.data)
# Out:
#         CRIM    ZN  INDUS CHAS    NOX     RM   AGE     DIS RAD    TAX  \
# 0    0.00632  18.0   2.31    0  0.538  6.575  65.2  4.0900   1  296.0
# 1    0.02731   0.0   7.07    0  0.469  6.421  78.9  4.9671   2  242.0
# 2    0.02729   0.0   7.07    0  0.469  7.185  61.1  4.9671   2  242.0
# 3    0.03237   0.0   2.18    0  0.458  6.998  45.8  6.0622   3  222.0
# 4    0.06905   0.0   2.18    0  0.458  7.147  54.2  6.0622   3  222.0
# ..       ...   ...    ...  ...    ...    ...   ...     ...  ..    ...
# 501  0.06263   0.0  11.93    0  0.573  6.593  69.1  2.4786   1  273.0
# 502  0.04527   0.0  11.93    0  0.573  6.120  76.7  2.2875   1  273.0
# 503  0.06076   0.0  11.93    0  0.573  6.976  91.0  2.1675   1  273.0
# 504  0.10959   0.0  11.93    0  0.573  6.794  89.3  2.3889   1  273.0
# 505  0.04741   0.0  11.93    0  0.573  6.030  80.8  2.5050   1  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# ...

# %%
print(boston.target)
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: MEDV, Length: 506, dtype: float64

# %%
print(boston.feature_names)
# Out:
# ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']

# %% [markdown]
# Preparing the dataset

# %%
df=pd.DataFrame(boston.data,columns=boston.feature_names)
df.head()
# Out:
#       CRIM    ZN  INDUS CHAS    NOX     RM   AGE     DIS RAD    TAX  PTRATIO  \
# 0  0.00632  18.0   2.31    0  0.538  6.575  65.2  4.0900   1  296.0     15.3
# 1  0.02731   0.0   7.07    0  0.469  6.421  78.9  4.9671   2  242.0     17.8
# 2  0.02729   0.0   7.07    0  0.469  7.185  61.1  4.9671   2  242.0     17.8
# 3  0.03237   0.0   2.18    0  0.458  6.998  45.8  6.0622   3  222.0     18.7
# 4  0.06905   0.0   2.18    0  0.458  7.147  54.2  6.0622   3  222.0     18.7
#
#         B  LSTAT
# 0  396.90   4.98
# 1  396.90   9.14
# 2  392.83   4.03
# 3  394.63   2.94
# 4  396.90   5.33

# %%
df['Price']=boston.target
df.head()
# Out:
#       CRIM    ZN  INDUS CHAS    NOX     RM   AGE     DIS RAD    TAX  PTRATIO  \
# 0  0.00632  18.0   2.31    0  0.538  6.575  65.2  4.0900   1  296.0     15.3
# 1  0.02731   0.0   7.07    0  0.469  6.421  78.9  4.9671   2  242.0     17.8
# 2  0.02729   0.0   7.07    0  0.469  7.185  61.1  4.9671   2  242.0     17.8
# 3  0.03237   0.0   2.18    0  0.458  6.998  45.8  6.0622   3  222.0     18.7
# 4  0.06905   0.0   2.18    0  0.458  7.147  54.2  6.0622   3  222.0     18.7
#
#         B  LSTAT  Price
# 0  396.90   4.98   24.0
# 1  396.90   9.14   21.6
# 2  392.83   4.03   34.7
# 3  394.63   2.94   33.4
# 4  396.90   5.33   36.2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    category
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    category
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  Price    506 non-null    float64
# dtypes: category(2), float64(12)
# memory usage: 49.0 KB

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS         NOX          RM         AGE  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.554695    6.284634   68.574901
# std      8.601545   23.322453    6.860353    0.115878    0.702617   28.148861
# min      0.006320    0.000000    0.460000    0.385000    3.561000    2.900000
# 25%      0.082045    0.000000    5.190000    0.449000    5.885500   45.025000
# 50%      0.256510    0.000000    9.690000    0.538000    6.208500   77.500000
# 75%      3.677083   12.500000   18.100000    0.624000    6.623500   94.075000
# max     88.976200  100.000000   27.740000    0.871000    8.780000  100.000000
#
#               DIS         TAX     PTRATIO           B       LSTAT       Price
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.795043  408.237154   18.455534  356.674032   12.653063   22.532806
# ...

# %%
df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# Price      0
# dtype: int64

# %% [markdown]
# EDA

# %%
import seaborn as sns
sns.pairplot(df)

# %%
df.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
plt.scatter(df['RM'],df['Price'])
plt.xlabel("RM")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.scatter(df['CRIM'],df['Price'])
plt.xlabel("CRIM")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
sns.regplot(x="RM",y="Price",data=df)
# Out:
# <Axes: xlabel='RM', ylabel='Price'>

# %%
sns.regplot(x="LSTAT",y="Price",data=df)
# Out:
# <Axes: xlabel='LSTAT', ylabel='Price'>

# %%
df['CHAS'] = df['CHAS'].astype(float)
sns.regplot(x="CHAS", y="Price", data=df)
# Out:
# <Axes: xlabel='CHAS', ylabel='Price'>

# %%
##Independent and Dependent dataset creation
X=df.iloc[:,:-1]
Y=df.loc[:,['Price']]

# %%
X.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS RAD    TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900   1  296.0     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671   2  242.0     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671   2  242.0     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622   3  222.0     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622   3  222.0     18.7
#
#         B  LSTAT
# 0  396.90   4.98
# 1  396.90   9.14
# 2  392.83   4.03
# 3  394.63   2.94
# 4  396.90   5.33

# %%
Y.head()
# Out:
#    Price
# 0   24.0
# 1   21.6
# 2   34.7
# 3   33.4
# 4   36.2

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test,=train_test_split(X,Y,test_size=0.3,random_state=100)

# %%
X_train
# Out:
#          CRIM    ZN  INDUS  CHAS     NOX     RM    AGE     DIS RAD    TAX  \
# 463   5.82115   0.0  18.10   0.0  0.7130  6.513   89.9  2.8016  24  666.0
# 75    0.09512   0.0  12.83   0.0  0.4370  6.286   45.0  4.5026   5  398.0
# 478  10.23300   0.0  18.10   0.0  0.6140  6.185   96.7  2.1705  24  666.0
# 199   0.03150  95.0   1.47   0.0  0.4030  6.975   15.3  7.6534   3  402.0
# 84    0.05059   0.0   4.49   0.0  0.4490  6.389   48.0  4.7794   3  247.0
# ..        ...   ...    ...   ...     ...    ...    ...     ...  ..    ...
# 343   0.02543  55.0   3.78   0.0  0.4840  6.696   56.4  5.7321   5  370.0
# 359   4.26131   0.0  18.10   0.0  0.7700  6.112   81.3  2.5091  24  666.0
# 323   0.28392   0.0   7.38   0.0  0.4930  5.708   74.3  4.7211   5  287.0
# 280   0.03578  20.0   3.33   0.0  0.4429  7.820   64.5  4.6947   5  216.0
# 8     0.21124  12.5   7.87   0.0  0.5240  5.631  100.0  6.0821   5  311.0
#
#      PTRATIO       B  LSTAT
# 463     20.2  393.82  10.29
# ...

# %%
Y_train
# Out:
#      Price
# 463   20.2
# 75    21.4
# 478   14.6
# 199   34.9
# 84    23.9
# ..     ...
# 343   23.9
# 359   22.6
# 323   18.5
# 280   45.4
# 8     16.5
#
# [354 rows x 1 columns]

# %%
X_test
# Out:
#         CRIM    ZN  INDUS  CHAS     NOX     RM    AGE     DIS RAD    TAX  \
# 198  0.03768  80.0   1.52   0.0  0.4040  7.274   38.3  7.3090   2  329.0
# 229  0.44178   0.0   6.20   0.0  0.5040  6.552   21.4  3.3751   8  307.0
# 502  0.04527   0.0  11.93   0.0  0.5730  6.120   76.7  2.2875   1  273.0
# 31   1.35472   0.0   8.14   0.0  0.5380  6.072  100.0  4.1750   4  307.0
# 315  0.25356   0.0   9.90   0.0  0.5440  5.705   77.7  3.9450   4  304.0
# ..       ...   ...    ...   ...     ...    ...    ...     ...  ..    ...
# 272  0.11460  20.0   6.96   0.0  0.4640  6.538   58.7  3.9175   3  223.0
# 124  0.09849   0.0  25.65   0.0  0.5810  5.879   95.8  2.0063   2  188.0
# 178  0.06642   0.0   4.05   0.0  0.5100  6.860   74.4  2.9153   5  296.0
# 447  9.92485   0.0  18.10   0.0  0.7400  6.251   96.6  2.1980  24  666.0
# 282  0.06129  20.0   3.33   1.0  0.4429  7.645   49.7  5.2119   5  216.0
#
#      PTRATIO       B  LSTAT
# 198     12.6  392.20   6.62
# 229     17.4  380.34   3.76
# ...

# %%
Y_test
# Out:
#      Price
# 198   34.6
# 229   31.5
# 502   20.6
# 31    14.5
# 315   16.2
# ..     ...
# 272   24.4
# 124   18.8
# 178   29.9
# 447   12.6
# 282   46.0
#
# [152 rows x 1 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
import pickle
pickle.dump(scaler,open("scaling.pkl","wb"))

# %%
X_train
# Out:
# array([[ 0.31902577, -0.50117334,  1.05764368, ...,  0.81714162,
#          0.39835958, -0.31513695],
#        [-0.41461915, -0.50117334,  0.27826616, ...,  0.10780338,
#          0.28090312, -0.49845825],
#        [ 0.884292  , -0.50117334,  1.05764368, ...,  0.81714162,
#          0.24175097,  0.73590517],
#        ...,
#        [-0.39042924, -0.50117334, -0.52773147, ...,  0.53340633,
#          0.36852409, -0.11823629],
#        [-0.42222206,  0.36490117, -1.12668384, ..., -1.68918683,
#          0.32615547, -1.20186887],
#        [-0.39974133,  0.04012323, -0.45526563, ..., -1.54731918,
#          0.31861341,  2.35184849]], shape=(354, 13))

# %%
X_test
# Out:
# array([[-0.42197862,  2.9631247 , -1.39436379, ..., -2.7768388 ,
#          0.38039174, -0.8134993 ],
#        [-0.3702035 , -0.50117334, -0.70224105, ..., -0.50695643,
#          0.24884938, -1.20186887],
#        [-0.42100616, -0.50117334,  0.14516563, ...,  1.19545535,
#          0.43252067, -0.47944715],
#        ...,
#        [-0.41829632, -0.50117334, -1.02020342, ..., -0.88527016,
#          0.37007687, -0.77276123],
#        [ 0.84481042, -0.50117334,  1.05764368, ...,  0.81714162,
#          0.3395759 ,  0.51999342],
#        [-0.4189536 ,  0.36490117, -1.12668384, ..., -1.68918683,
#          0.21258095, -1.30371403]], shape=(152, 13))

# %%
Y_train
# Out:
#      Price
# 463   20.2
# 75    21.4
# 478   14.6
# 199   34.9
# 84    23.9
# ..     ...
# 343   23.9
# 359   22.6
# 323   18.5
# 280   45.4
# 8     16.5
#
# [354 rows x 1 columns]

# %% [markdown]
# Model Training

# %%
from sklearn.linear_model import LinearRegression
regression=LinearRegression()
regression.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
##printing the coefficients and intercept
print(regression.coef_)
# Out:
# [[-0.60033443  0.91337983 -0.04123957  0.67387317 -1.52448856  2.76096722
#   -0.34091223 -2.81997448  2.45481024 -2.36183297 -1.94244355  0.95375187
#   -3.22519325]]

# %%
print(regression.intercept_)
# Out:
# [22.60225989]

# %%
reg_pred=regression.predict(X_test)

# %%
reg_pred
# Out:
# array([[34.01651319],
#        [31.05189517],
#        [22.33884524],
#        [18.0838353 ],
#        [20.56688064],
#        [25.98808555],
#        [26.01540609],
#        [23.82611577],
#        [22.21599346],
#        [19.28360875],
#        [26.66123555],
#        [16.98260577],
#        [20.99150244],
#        [15.24603617],
#        [41.09899335],
#        [20.25245593],
#        [28.49362648],
#        [19.02746332],
#        [32.1219971 ],
#        [40.55013347],
#        [34.85510783],
#        [16.62558247],
#        [20.26594393],
#        [17.78965573],
#        [13.61712506],
#        [12.31506816],
#        [27.30863471],
#        [20.08837791],
#        [18.3960775 ],
#        [20.36652738],
#        [15.63267698],
#        [24.40174268],
#        [38.95380335],
#        [24.82674   ],
#        [31.67752332],
#        [28.52641185],
#        [14.69895345],
#        [14.24630553],
#        [16.49088419],
#        [23.30593651],
#        [23.14883147],
# ...

# %%
##plotting a scatter plot for the prediction
plt.scatter(Y_test,reg_pred)

# %%
##calculating residuals
residuals=Y_test-reg_pred

# %%
residuals
# Out:
#         Price
# 198  0.583487
# 229  0.448105
# 502 -1.738845
# 31  -3.583835
# 315 -4.366881
# ..        ...
# 272 -3.814334
# 124 -1.892753
# 178 -1.061978
# 447 -5.559312
# 282  6.326232
#
# [152 rows x 1 columns]

# %%
##plotting this residuals
sns.displot(residuals,kind="kde")

# %%
plt.scatter(reg_pred,residuals)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
print(mean_absolute_error(Y_test,reg_pred))
print(mean_squared_error(Y_test,reg_pred))
print(np.sqrt(mean_squared_error(Y_test,reg_pred)))
# Out:
# 3.4719478482701627
# 29.798844301478827
# 5.458831770761838

# %% [markdown]
# R square and adjusted R square

# %% [markdown]
# Formula
#
# R^2 = 1 - SSR/SST
#
# R^2 = coefficient of determination SSR = sum of squares of residuals SST = total sum of squares

# %%
from sklearn.metrics import r2_score
score=r2_score(Y_test,reg_pred)
print(score)
# Out:
# 0.705791987326454

# %% [markdown]
# Adjusted R2 = 1 – [(1-R2)*(n-1)/(n-k-1)]
#
# where:
#
# R2: The R2 of the model n: The number of observations k: The number of predictor variables

# %%
#display adjusted R-squared
1 - (1-score)*(len(Y_test)-1)/(len(Y_test)-X_test.shape[1]-1)
# Out:
# 0.6780767397557577

# %% [markdown]
# New Data Prediction

# %%
data_array
# Out:
# array([[0.00632, 18.0, 2.31, ..., 15.3, 396.9, 4.98],
#        [0.02731, 0.0, 7.07, ..., 17.8, 396.9, 9.14],
#        [0.02729, 0.0, 7.07, ..., 17.8, 392.83, 4.03],
#        ...,
#        [0.06076, 0.0, 11.93, ..., 21.0, 396.9, 5.64],
#        [0.10959, 0.0, 11.93, ..., 21.0, 393.45, 6.48],
#        [0.04741, 0.0, 11.93, ..., 21.0, 396.9, 7.88]],
#       shape=(506, 13), dtype=object)

# %%
data_array[0].shape
# Out:
# (13,)

# %%
data_array[0].reshape(1,-1)
# Out:
# array([[0.00632, 18.0, 2.31, '0', 0.538, 6.575, 65.2, 4.09, '1', 296.0,
#         15.3, 396.9, 4.98]], dtype=object)

# %%
##transformation(standardisation of new data)
new_data = pd.DataFrame(data_array[0].reshape(1,-1), columns=scaler.feature_names_in_)
transformed_data = scaler.transform(new_data)

# %%
regression.predict(transformed_data)
# Out:
# array([[29.68751886]])

# %%
import pickle
pickle.dump(regression,open("regmodel.pkl","wb"))

# %%
pickled_model=pickle.load(open("regmodel.pkl","rb"))

# %%
##prediction
pickled_model.predict(scaler.transform(new_data))
# Out:
# array([[29.68751886]])

# %%
import joblib
joblib.dump(X_train, 'X_train1.pkl')
# Out:
# ['X_train1.pkl']

# %%
Y_train
# Out:
#      Price
# 463   20.2
# 75    21.4
# 478   14.6
# 199   34.9
# 84    23.9
# ..     ...
# 343   23.9
# 359   22.6
# 323   18.5
# 280   45.4
# 8     16.5
#
# [354 rows x 1 columns]

# %%
Y_train1=scaler.fit_transform(Y_train)
Y_train1
# Out:
# array([[-2.73475640e-01],
#        [-1.36866454e-01],
#        [-9.10985176e-01],
#        [ 1.39998689e+00],
#        [ 1.47736017e-01],
#        [ 6.80473253e-02],
#        [-6.60535001e-01],
#        [-7.85760088e-01],
#        [-2.27939245e-01],
#        [ 1.02431163e+00],
#        [ 1.24967820e-01],
#        [-6.14998606e-01],
#        [ 1.18368901e+00],
#        [ 6.94172762e-01],
#        [-7.99459597e-02],
#        [ 2.95729302e-01],
#        [-2.27939245e-01],
#        [-7.28839594e-01],
#        [ 6.94172762e-01],
#        [-6.85618609e-02],
#        [-4.10084826e-01],
#        [ 1.39998689e+00],
#        [ 6.14484070e-01],
#        [-2.57267771e-04],
#        [-2.57267771e-04],
#        [-5.46694012e-01],
#        [ 7.28325058e-01],
#        [-3.75932530e-01],
#        [ 1.63905297e+00],
#        [-6.26382704e-01],
#        [-4.55621222e-01],
#        [ 2.25109299e-02],
#        [-3.19012036e-01],
#        [-8.88216978e-01],
#        [-1.02714157e-01],
# ...

# %%
joblib.dump(Y_train1, 'Y_train1.pkl')
# Out:
# ['Y_train1.pkl']

# %%
print(X_train.shape)
# Out:
# (354, 13)

# %%
X_train
# Out:
# array([[ 0.31902577, -0.50117334,  1.05764368, ...,  0.81714162,
#          0.39835958, -0.31513695],
#        [-0.41461915, -0.50117334,  0.27826616, ...,  0.10780338,
#          0.28090312, -0.49845825],
#        [ 0.884292  , -0.50117334,  1.05764368, ...,  0.81714162,
#          0.24175097,  0.73590517],
#        ...,
#        [-0.39042924, -0.50117334, -0.52773147, ...,  0.53340633,
#          0.36852409, -0.11823629],
#        [-0.42222206,  0.36490117, -1.12668384, ..., -1.68918683,
#          0.32615547, -1.20186887],
#        [-0.39974133,  0.04012323, -0.45526563, ..., -1.54731918,
#          0.31861341,  2.35184849]], shape=(354, 13))
